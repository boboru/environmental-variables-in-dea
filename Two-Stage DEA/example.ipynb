# %%
import numpy as np
import pandas as pd
from scipy.stats import norm
from scipy.stats import uniform
from truncreg import Truncreg
import DEA

# %%
#=============================================== Monte-Carlo ===============================================
#trial
trial = 10

beta1_mean_list = []
beta1_std_list = []
beta2_mean_list = []
beta2_std_list = []
sigma_mean_list = []
sigma_std_list = []

for t in range(trial):
    #=============================================== DGP ===============================================
    # sample size
    n = 100 #400

    # beta
    beta_1 = 0.5
    beta_2 = 0.5

    # generate environment variable z
    np.random.seed(seed=3*t)
    mu_z = 2
    sigma_z = 2
    z = norm.rvs(mu_z,sigma_z,size=n)
    zn = norm.rvs(mu_z,sigma_z,size=n)

    # generate error term
    np.random.seed(seed=3*t+1)
    sigma_e = 1
    error = norm.rvs(0,sigma_e,size=n)

    # generate inefficiency U
    delta = beta_1 + z*beta_2 + error
    for i in range(n): # left-truncated
        if delta[i] < 1:
            delta[i] = 1

    # generate input x
    np.random.seed(seed=3*t+3)
    x = uniform.rvs(6,16,size=n)

    # generate output y
    y = (delta**-1) * (x**(3/4))


    #=============================================== DEA ===============================================
    # DataFrame
    DMU_index = list(range(0,n))
    DMU = [str(x) for x in DMU_index]
    df_Y = pd.DataFrame({'Y':y},index=DMU)
    df_X = pd.DataFrame({'X':x},index=DMU)
    Y = df_Y.T.to_dict('list')
    X = df_X.T.to_dict('list')

    # input-oriented VRS (dual)
    d = DEA.VRS(DMU, X, Y, orientation="output", dual=True)

    #=============================================== Truncated Regression ===============================================
    # DataFrame
    #df = pd.DataFrame({'D': d, 'D_trunc':d, 'Z':z})
    df = pd.DataFrame({'D': d, 'D_trunc':d, 'Z':z, 'Zn':zn})

    # Truncated Data
    left = 1
    cond = (df.loc[:,'D'] <= left)
    df.loc[cond,'D_trunc'] = np.nan
    d_trunc = df['D_trunc']

    # Fitting Truncated Regression
    formula_trunc = 'D_trunc ~ Z'
    res_trunc = Truncreg.from_formula(formula_trunc,left=1,data=df).fit()
    print(res_trunc.summary().tables[1])
    df_trunc = pd.read_html(res_trunc.summary().tables[1].as_html(),header=0,index_col=0)[0]
    beta1_h = df_trunc.coef[0]
    beta2_h = df_trunc.coef[1]
    sigma_h = np.mean(res_trunc.resid**2)

    #=============================================== Bootstrap Estimation ===============================================
    B = 10
    beta1_b_list = []
    beta2_b_list = []
    sigma_b_list = []
    for b in range(B):
        #1
        np.random.seed(seed=b)
        eps = norm.rvs(0, sigma_h, size=n)
        for i in range(n):
            if eps[i] < 1-z[i]*beta2_h - beta1_h:
                eps[i] = 1-z[i]*beta2_h - beta1_h
            else:
                eps[i] = eps[i]

        #2
        d_s = beta1_h + z*beta2_h + eps

        #3
        # DataFrame
        df_b = pd.DataFrame({'D': d_s, 'D_trunc': d_s, 'Z': z})

        # Truncated Data
        left = 1
        cond = (df_b.loc[:, 'D'] <= left)
        df_b.loc[cond, 'D_trunc'] = np.nan
        d_trunc = df_b['D_trunc']

        # Fitting Truncated Regression
        formula_trunc = 'D_trunc ~ Z'
        res_b_trunc = Truncreg.from_formula(formula_trunc, left=1, data=df_b).fit()
        df_b_trunc = pd.read_html(res_b_trunc.summary().tables[1].as_html(), header=0, index_col=0)[0]
        beta1_b = df_b_trunc.coef[0]
        beta2_b = df_b_trunc.coef[1]
        sigma_b = np.mean(res_b_trunc.resid ** 2)
        beta1_b_list.append(beta1_b)
        beta2_b_list.append(beta2_b)
        sigma_b_list.append(sigma_b)
        print('b=',b)
    beta1_mean_list.append(np.mean(beta1_b_list))
    beta1_std_list.append(np.std(beta1_b_list))
    beta2_mean_list.append(np.mean(beta2_b_list))
    beta2_std_list.append(np.std(beta2_b_list))
    sigma_mean_list.append(np.mean(sigma_b_list))
    sigma_std_list.append(np.std(sigma_b_list))
print(beta1_mean_list, beta1_std_list)
print(beta2_mean_list, beta2_std_list)
print(sigma_mean_list, sigma_std_list)

alpha = 0.95 # 0.9 0.95, 0.975, 0.995 (0.8, 0.9, 0.95, 0.99)
beta1_lb_list = np.add(beta1_mean_list, [-norm.ppf(alpha, loc=0, scale=1)*i for i in beta1_std_list])
beta1_ub_list = np.add(beta1_mean_list, [norm.ppf(alpha, loc=0, scale=1)*i for i in beta1_std_list])
beta2_lb_list = np.add(beta2_mean_list, [-norm.ppf(alpha, loc=0, scale=1)*i for i in beta2_std_list])
beta2_ub_list = np.add(beta2_mean_list, [norm.ppf(alpha, loc=0, scale=1)*i for i in beta2_std_list])
sigma_lb_list = np.add(sigma_mean_list, [-norm.ppf(alpha, loc=0, scale=1)*i for i in sigma_std_list])
sigma_ub_list = np.add(sigma_mean_list, [norm.ppf(alpha, loc=0, scale=1)*i for i in sigma_std_list])
beta1_in = 0
beta2_in = 0
sigma_in = 0
for i in range(trial):
    if beta1_lb_list[i] < 0.5 and beta1_ub_list[i] > 0.5:
        beta1_in += 1
    if beta2_lb_list[i] < 0.5 and beta2_ub_list[i] > 0.5:
        beta2_in += 1
    if sigma_lb_list[i] < 1 and sigma_ub_list[i] > 1:
        sigma_in += 1
print(beta1_in)
print(beta2_in)
print(sigma_in)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.909950
#          Iterations: 63
#          Function evaluations: 116
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -0.0609      0.499     -0.122      0.903      -1.038       0.916
# Z              0.6720      0.113      5.937      0.000       0.450       0.894
# Log(Sigma)    -0.0914      0.135     -0.677      0.498      -0.356       0.173
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: -18.155899
#          Iterations: 245
#          Function evaluations: 457
# c:\Users\NTUpo\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.780614
#          Iterations: 69
#          Function evaluations: 121
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.842634
#          Iterations: 62
#          Function evaluations: 116
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.864864
#          Iterations: 61
#          Function evaluations: 112
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.835933
#          Iterations: 76
#          Function evaluations: 131
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.785519
#          Iterations: 78
#          Function evaluations: 133
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.940365
#          Iterations: 73
#          Function evaluations: 136
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.774285
#          Iterations: 70
#          Function evaluations: 123
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.951374
#          Iterations: 76
#          Function evaluations: 134
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.802123
#          Iterations: 83
#          Function evaluations: 145
# b= 9
# Optimization terminated successfully.
#          Current function value: 0.958950
#          Iterations: 77
#          Function evaluations: 132
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.6382      0.421      1.515      0.130      -0.188       1.464
# Z              0.5272      0.099      5.320      0.000       0.333       0.721
# Log(Sigma)    -0.1364      0.136     -1.005      0.315      -0.402       0.130
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.767169
#          Iterations: 55
#          Function evaluations: 105
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.715906
#          Iterations: 62
#          Function evaluations: 108
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.748473
#          Iterations: 67
#          Function evaluations: 115
# b= 2
# Optimization terminated successfully.
#          Current function value: -18.159616
#          Iterations: 230
#          Function evaluations: 445
# c:\Users\NTUpo\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.758054
#          Iterations: 75
#          Function evaluations: 132
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.694704
#          Iterations: 60
#          Function evaluations: 110
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.703708
#          Iterations: 53
#          Function evaluations: 97
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.778431
#          Iterations: 71
#          Function evaluations: 127
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.905277
#          Iterations: 65
#          Function evaluations: 119
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.845912
#          Iterations: 64
#          Function evaluations: 113
# b= 9
# Optimization terminated successfully.
#          Current function value: 0.995515
#          Iterations: 67
#          Function evaluations: 124
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.4216      0.467      0.903      0.366      -0.493       1.336
# Z              0.5318      0.106      5.006      0.000       0.324       0.740
# Log(Sigma)    -0.0484      0.135     -0.358      0.720      -0.313       0.216
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.928314
#          Iterations: 65
#          Function evaluations: 119
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.721036
#          Iterations: 67
#          Function evaluations: 123
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.866594
#          Iterations: 59
#          Function evaluations: 113
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.913721
#          Iterations: 73
#          Function evaluations: 125
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.861876
#          Iterations: 72
#          Function evaluations: 130
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.948714
#          Iterations: 59
#          Function evaluations: 106
# b= 5
# Optimization terminated successfully.
#          Current function value: -18.669808
#          Iterations: 392
#          Function evaluations: 762
# c:\Users\NTUpo\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.887350
#          Iterations: 61
#          Function evaluations: 110
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.877212
#          Iterations: 77
#          Function evaluations: 134
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.894209
#          Iterations: 58
#          Function evaluations: 107
# b= 9
# Optimization terminated successfully.
#          Current function value: 1.012234
#          Iterations: 65
#          Function evaluations: 115
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.0995      0.366      3.002      0.003       0.382       1.817
# Z              0.3404      0.091      3.731      0.000       0.162       0.519
# Log(Sigma)    -0.1143      0.139     -0.825      0.409      -0.386       0.157
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.687032
#          Iterations: 56
#          Function evaluations: 103
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.622568
#          Iterations: 56
#          Function evaluations: 102
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.632554
#          Iterations: 60
#          Function evaluations: 111
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.643264
#          Iterations: 62
#          Function evaluations: 114
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.620700
#          Iterations: 64
#          Function evaluations: 119
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.625538
#          Iterations: 51
#          Function evaluations: 98
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.665340
#          Iterations: 55
#          Function evaluations: 100
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.672031
#          Iterations: 53
#          Function evaluations: 97
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.748166
#          Iterations: 56
#          Function evaluations: 105
# b= 8
# Optimization terminated successfully.
#          Current function value: -18.232284
#          Iterations: 285
#          Function evaluations: 548
# c:\Users\NTUpo\AppData\Local\Programs\Python\Python39\lib\site-packages\statsmodels\base\model.py:592: HessianInversionWarning: Inverting hessian failed, no bse or cov_params available
#   warnings.warn('Inverting hessian failed, no bse or cov_params '
# b= 9
# Optimization terminated successfully.
#          Current function value: 0.971926
#          Iterations: 46
#          Function evaluations: 86
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      1.3297      0.283      4.695      0.000       0.775       1.885
# Z              0.3131      0.074      4.212      0.000       0.167       0.459
# Log(Sigma)    -0.2413      0.128     -1.878      0.060      -0.493       0.011
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.520622
#          Iterations: 49
#          Function evaluations: 91
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.466496
#          Iterations: 51
#          Function evaluations: 92
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.557436
#          Iterations: 54
#          Function evaluations: 100
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.549167
#          Iterations: 54
#          Function evaluations: 97
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.488235
#          Iterations: 47
#          Function evaluations: 86
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.470141
#          Iterations: 45
#          Function evaluations: 81
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.518798
#          Iterations: 56
#          Function evaluations: 99
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.481172
#          Iterations: 47
#          Function evaluations: 90
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.624333
#          Iterations: 57
#          Function evaluations: 103
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.600657
#          Iterations: 52
#          Function evaluations: 96
# b= 9
# Optimization terminated successfully.
#          Current function value: 1.076115
#          Iterations: 80
#          Function evaluations: 144
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1392      0.780      0.178      0.858      -1.389       1.668
# Z              0.5302      0.156      3.399      0.001       0.224       0.836
# Log(Sigma)     0.1659      0.180      0.922      0.357      -0.187       0.519
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 1.222594
#          Iterations: 85
#          Function evaluations: 154
# b= 0
# Optimization terminated successfully.
#          Current function value: 1.119034
#          Iterations: 66
#          Function evaluations: 122
# b= 1
# Optimization terminated successfully.
#          Current function value: 1.069416
#          Iterations: 101
#          Function evaluations: 183
# b= 2
# Optimization terminated successfully.
#          Current function value: 1.226208
#          Iterations: 98
#          Function evaluations: 175
# b= 3
# Optimization terminated successfully.
#          Current function value: 1.235021
#          Iterations: 82
#          Function evaluations: 149
# b= 4
# Optimization terminated successfully.
#          Current function value: 1.194153
#          Iterations: 97
#          Function evaluations: 174
# b= 5
# Optimization terminated successfully.
#          Current function value: 1.242880
#          Iterations: 86
#          Function evaluations: 152
# b= 6
# Optimization terminated successfully.
#          Current function value: 1.201186
#          Iterations: 88
#          Function evaluations: 157
# b= 7
# Optimization terminated successfully.
#          Current function value: 1.243754
#          Iterations: 88
#          Function evaluations: 154
# b= 8
# Optimization terminated successfully.
#          Current function value: 1.216690
#          Iterations: 101
#          Function evaluations: 178
# b= 9
# Optimization terminated successfully.
#          Current function value: 0.918485
#          Iterations: 62
#          Function evaluations: 110
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.3056      0.389      0.786      0.432      -0.456       1.068
# Z              0.5370      0.082      6.547      0.000       0.376       0.698
# Log(Sigma)    -0.1579      0.124     -1.269      0.205      -0.402       0.086
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.844193
#          Iterations: 58
#          Function evaluations: 107
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.592086
#          Iterations: 64
#          Function evaluations: 113
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.794757
#          Iterations: 62
#          Function evaluations: 109
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.743426
#          Iterations: 53
#          Function evaluations: 99
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.703120
#          Iterations: 62
#          Function evaluations: 113
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.706505
#          Iterations: 64
#          Function evaluations: 115
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.699024
#          Iterations: 55
#          Function evaluations: 99
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.797945
#          Iterations: 57
#          Function evaluations: 104
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.859511
#          Iterations: 63
#          Function evaluations: 117
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.731342
#          Iterations: 69
#          Function evaluations: 122
# b= 9
# Optimization terminated successfully.
#          Current function value: 0.989622
#          Iterations: 73
#          Function evaluations: 129
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1916      0.477      0.402      0.688      -0.742       1.126
# Z              0.5856      0.104      5.657      0.000       0.383       0.788
# Log(Sigma)    -0.0857      0.134     -0.639      0.523      -0.349       0.177
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.875291
#          Iterations: 64
#          Function evaluations: 120
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.837668
#          Iterations: 61
#          Function evaluations: 110
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.917784
#          Iterations: 70
#          Function evaluations: 133
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.977894
#          Iterations: 62
#          Function evaluations: 115
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.858581
#          Iterations: 58
#          Function evaluations: 109
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.936305
#          Iterations: 63
#          Function evaluations: 111
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.916116
#          Iterations: 67
#          Function evaluations: 123
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.940992
#          Iterations: 59
#          Function evaluations: 110
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.961155
#          Iterations: 80
#          Function evaluations: 146
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.902248
#          Iterations: 58
#          Function evaluations: 103
# b= 9
# Optimization terminated successfully.
#          Current function value: 1.139467
#          Iterations: 92
#          Function evaluations: 163
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     -1.4171      1.487     -0.953      0.341      -4.332       1.498
# Z              0.8230      0.274      3.005      0.003       0.286       1.360
# Log(Sigma)     0.3910      0.204      1.919      0.055      -0.008       0.790
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 1.780919
#          Iterations: 76
#          Function evaluations: 141
# b= 0
# Optimization terminated successfully.
#          Current function value: 1.649930
#          Iterations: 68
#          Function evaluations: 124
# b= 1
# Optimization terminated successfully.
#          Current function value: 1.594116
#          Iterations: 96
#          Function evaluations: 178
# b= 2
# Optimization terminated successfully.
#          Current function value: 1.770099
#          Iterations: 77
#          Function evaluations: 139
# b= 3
# Optimization terminated successfully.
#          Current function value: 1.711516
#          Iterations: 145
#          Function evaluations: 259
# b= 4
# Optimization terminated successfully.
#          Current function value: 1.791003
#          Iterations: 88
#          Function evaluations: 153
# b= 5
# Optimization terminated successfully.
#          Current function value: 1.817736
#          Iterations: 77
#          Function evaluations: 145
# b= 6
# Optimization terminated successfully.
#          Current function value: 1.790158
#          Iterations: 110
#          Function evaluations: 191
# b= 7
# Optimization terminated successfully.
#          Current function value: 1.824217
#          Iterations: 115
#          Function evaluations: 203
# b= 8
# Optimization terminated successfully.
#          Current function value: 1.772004
#          Iterations: 103
#          Function evaluations: 184
# b= 9
# Optimization terminated successfully.
#          Current function value: 1.009631
#          Iterations: 65
#          Function evaluations: 118
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.7131      0.483      1.477      0.140      -0.233       1.660
# Z              0.4135      0.116      3.555      0.000       0.185       0.641
# Log(Sigma)    -0.0664      0.151     -0.439      0.660      -0.362       0.230
# ==============================================================================
# Optimization terminated successfully.
#          Current function value: 0.800247
#          Iterations: 59
#          Function evaluations: 110
# b= 0
# Optimization terminated successfully.
#          Current function value: 0.647642
#          Iterations: 61
#          Function evaluations: 112
# b= 1
# Optimization terminated successfully.
#          Current function value: 0.755565
#          Iterations: 65
#          Function evaluations: 116
# b= 2
# Optimization terminated successfully.
#          Current function value: 0.758121
#          Iterations: 51
#          Function evaluations: 98
# b= 3
# Optimization terminated successfully.
#          Current function value: 0.687938
#          Iterations: 53
#          Function evaluations: 96
# b= 4
# Optimization terminated successfully.
#          Current function value: 0.669241
#          Iterations: 79
#          Function evaluations: 138
# b= 5
# Optimization terminated successfully.
#          Current function value: 0.722927
#          Iterations: 53
#          Function evaluations: 98
# b= 6
# Optimization terminated successfully.
#          Current function value: 0.755338
#          Iterations: 53
#          Function evaluations: 98
# b= 7
# Optimization terminated successfully.
#          Current function value: 0.811430
#          Iterations: 61
#          Function evaluations: 108
# b= 8
# Optimization terminated successfully.
#          Current function value: 0.677761
#          Iterations: 62
#          Function evaluations: 114
# b= 9
# [-0.26456999999999997, 0.50219, 0.14537, 0.99428, 1.3493499999999998, -0.22137, 0.32183, 0.11740999999999997, -6.04063, 0.84742] [0.40407266190624674, 0.4071344997663549, 0.4361778675036137, 0.27519575505447025, 0.12454938980179714, 1.1735941871447728, 0.19141908499415622, 0.42564968565711403, 4.944630712611408, 0.21911953267566084]
# [0.75591, 0.5879099999999999, 0.61883, 0.39821999999999996, 0.3123, 0.5635699999999999, 0.53683, 0.61134, 1.73539, 0.37973] [0.1438672544396396, 0.13319218032602365, 0.15135964488594705, 0.10039907170885595, 0.04389867879560841, 0.2307169436777455, 0.047663404200707256, 0.09800997092133021, 0.7988185106142697, 0.05563915977079453]
# [0.9793343444588267, 0.5065851084608312, 0.7352784266216383, 0.3182717317851976, 0.23339331141065162, 2.7440985733660765, 0.46468402653631474, 0.6953434781093335, 41.316891193774396, 0.3751558212851981] [0.2540790889215276, 0.2127957271014681, 0.2660641476532297, 0.10364470938931246, 0.041438687737821334, 1.8576518483247926, 0.10545597038197099, 0.20434940506868232, 46.09627998149817, 0.07440915052274073]
# 7
# 7
# 5
